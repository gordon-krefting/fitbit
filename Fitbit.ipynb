# %%
import pandas as pd
import matplotlib

# %matplotlib inline

df = pd.read_csv("data/data.csv").set_index('Time')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1430 entries, 2019-04-02 00:00:00 to 2019-04-02 23:59:00
# Data columns (total 3 columns):
# Heart Rate               1430 non-null int64
# Fairly Active Minutes    1430 non-null int64
# Very Active Minutes      1430 non-null int64
# dtypes: int64(3)
# memory usage: 44.7+ KB

# %%
df
# Out:
#                      Heart Rate  Fairly Active Minutes  Very Active Minutes
# Time
# 2019-04-02 00:00:00          65                      0                    0
# 2019-04-02 00:01:00          65                      0                    0
# 2019-04-02 00:02:00          65                      0                    0
# 2019-04-02 00:03:00          64                      0                    0
# 2019-04-02 00:04:00          63                      0                    0
# 2019-04-02 00:05:00          63                      0                    0
# 2019-04-02 00:06:00          64                      0                    0
# 2019-04-02 00:07:00          65                      0                    0
# 2019-04-02 00:08:00          64                      0                    0
# 2019-04-02 00:09:00          63                      0                    0
# 2019-04-02 00:10:00          63                      0                    0
# ...

# %%
df['Active Minutes'] = df['Fairly Active Minutes'] + df['Very Active Minutes']
df = df.drop(columns=['Fairly Active Minutes', 'Very Active Minutes'])
df['Active Minutes'] = df['Active Minutes'] * 115

df.plot(figsize=(20,10))

# %%
df.sum(axis = 0, skipna = True) / 115
# Out:
# Heart Rate        958.843478
# Active Minutes    110.000000
# dtype: float64
